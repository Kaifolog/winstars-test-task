# %%
from datasets import load_dataset
animal_facts = load_dataset("Rapidata/Animals-10")['train']
animal_facts.features
# Out:
# {'image': Image(mode=None, decode=True, id=None),
#  'label': ClassLabel(names=['Butterfly', 'Cat', 'Chicken', 'Cow', 'Dog', 'Elephant', 'Horse', 'Sheep', 'Spider', 'Squirrel'], id=None)}

# %%
from collections import Counter
import matplotlib.pyplot as plt

label_dict = dict(Counter(animal_facts["label"]))
print(label_dict)

keys = list(label_dict.keys())
values = list(label_dict.values())

plt.bar(keys, values)

plt.xlabel('Category')
plt.ylabel('Frequency')
plt.title('Histogram from of NER classes')

plt.show()
# Out:
# {0: 1603, 1: 1199, 2: 2993, 3: 1797, 4: 4811, 5: 1037, 6: 2598, 7: 1376, 8: 4340, 9: 1800}

# %% [markdown]
# Classes are roughly imbalanced, I will downsample them.

# %%
animal_facts[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=290x300>,
#  'label': 0}

# %%
animal_facts['image'][0]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=290x300>
